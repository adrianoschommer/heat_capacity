# %% [markdown]
# # Heat Capacity of a Lithium-Ion cell
#
# Heat capacity $C\left[\frac{J}{K}\right]$ is comonly measured by an equipement called [calorimeter](https://en.wikipedia.org/wiki/Calorimeter), which is available in specialized laboratories but not commonly found in battery test labs. The question is: is it possible to determine specific heat capacity of a Lithium-Ion cell using basic battery testing lab equipments? In this notebook we investigate a method proposed by Bryden et al (2018) using a cell cycler, thermocouples and a thermal chamber.
#
# Before we start, let's remeber what is [heat capacity](https://en.wikipedia.org/wiki/Heat_capacity) first of all. Imagine you are baking an object X, how much heat you should provide for it to change $1[K]$ of it's tempetature is the heat capacity $C\left[\frac{J}{K}\right]$ of that object. In other words, it depends on the charateristics of that objetc, such as mass. To compare diferent materials independent of their mass, we use specific heat capacity $C_{p}\left[\frac{J}{K\cdot kg}\right]$, which is the amount of heat you should provide to change $1[K]$ of $1[kg]$ of a give material.
#
# Second, why do we need it? Heat capacity is an important input for thermal modeling in general. When it comes to battery pack design, thermal modeling is critical due to the sensible nature of Lithium-Ion cells to temperatures, specially above $60^{\circ}C$ when thermal runaway could occur.
#
# Now, let's get started. The method investigated consists of:
#
# 1. Simplified thermal model derivation;
# 2. Experiments to measure internal cell heat generation and external thermal resistance using a cell cycler, thermocouples and a thermal chamber;
# 3. Heat capacity and internal resistance calculations.

# %% [markdown]
# ## Thermal model
#
# Essentially the thermal model is needed to define which parameters we can measure and which variables we can calculate to find out the specific heat capacity $C_{p}$ of a given cell. This method take advantage of a lumped-parameter thermal model developed by Forgez et al (2010), in which the internal temperature of the battery is estimated based on it's surface temperature. In this model, heat transfer coefficient includes conduction, convection and radiation mechanisms. The general idea could be thought as:
#
# 1. Heat is generated in a single point (1) inside the cell, $\dot{Q}_{gen}[W]$;
#
# 2. Heat is transfered from point (1) which is at temperature $T_{1}[K]$ to to the cell surface (2) at $T_{s}[K]$;
#
# 3. Heat is transfered from the cell surface (2) which is at $T_{s}[K]$ to to the ambient (3) at temperature $T_{a}[K]$.
#
# If we perform a heat balance at the point inside the cell, we have heat being generated $\dot{Q}_{gen}$ minus the heat that flows to the cell surface. This phenomenon depends uppon the heat transfer coefficient $h\left[\frac{W}{K\cdot m^{2}}\right]$, the area $A[m^{2}]$ thorugh the heat is being trasfered and the difference between $T_{1}$ and $T_{s}$. Finally, this is related to the heat capacity $C_{p}$ and the rate at which temperature $T_{1}$ changes over time $\frac{dTi}{dt}$, Equation 1 below but first let us use sympy to manipulate the equations:

# %%
import sympy as sp
from sympy import Derivative
sp.init_printing()

# %%
#defining symbols for symbolic manipulation:
Cp, Ta, Rin, Rout, t, A, h = sp.symbols('C_p, T_a, R_in, R_out, t, A, h')

#defining time dependent variables:
Ti, Ts, Qdot_gen= sp.symbols('T_i, T_s, \dot{Q}_{gen}', cls=sp.Function)
Ti = Ti(t)
Ts = Ts(t)
Qdot_gen = Qdot_gen(t)

# %%
equation_1 = sp.Eq(Cp * sp.Derivative(Ti, t), (Qdot_gen - (h * A) * (Ti - Ts)))
equation_1
# Out:
#    d
# Cₚ⋅──(Tᵢ(t)) = -A⋅h⋅(Tᵢ(t) - Tₛ(t)) + \dot{Q}_{gen}(t)
#    dt

# %% [markdown]
# Because the area does not change throught the experiments, Brayden (2018) simplies Equation 1 using the inverse of internal thermal resistance $\frac{1}{R_{in}}\left[\frac{W}{K}\right]$ instead of $hA$ term, which lead us to Equation 2:

# %%
equation_2 = sp.Eq(Cp * sp.Derivative(Ti, t), (Qdot_gen - (1 / Rin) * (Ti - Ts)))
equation_2
# Out:
#    d                              Tᵢ(t) - Tₛ(t)
# Cₚ⋅──(Tᵢ(t)) = \dot{Q}_{gen}(t) - ─────────────
#    dt                                  Rᵢₙ

# %% [markdown]
# Thermal resistance can be defined as how difficult is for heat to flow throught a material. Unfortunately it is not pratical to measure because it would imply placing a thermocouple inside the cell. To eliminate $R_{in}$ from Equation 2, a energy balance is performed at the surface of the cell:

# %%
equation_3 = sp.Eq((1 / Rin) * (Ti - Ts), (1 / Rout) * (Ts - Ta))
equation_3
# Out:
# Tᵢ(t) - Tₛ(t)   -Tₐ + Tₛ(t)
# ───────────── = ───────────
#      Rᵢₙ            Rₒᵤₜ

# %% [markdown]
# Isolating $T_{i}$ we have:

# %%
equation_4 = sp.Eq(Ti, sp.solve(equation_3, Ti)[0]) #sp.solve returns a list
equation_4
# Out:
#         -Rᵢₙ⋅Tₐ + Rᵢₙ⋅Tₛ(t) + Rₒᵤₜ⋅Tₛ(t)
# Tᵢ(t) = ────────────────────────────────
#                       Rₒᵤₜ

# %% [markdown]
# Substituting $T_{1}$ into Equation 2 give us:

# %%
equation_5 = equation_2.subs(Ti, equation_4.rhs).simplify()
equation_5
# Out:
#                                         ⎛    d                d        ⎞
#                                      Cₚ⋅⎜Rᵢₙ⋅──(Tₛ(t)) + Rₒᵤₜ⋅──(Tₛ(t))⎟
# Rₒᵤₜ⋅\dot{Q}_{gen}(t) + Tₐ - Tₛ(t)      ⎝    dt               dt       ⎠
# ────────────────────────────────── = ───────────────────────────────────
#                Rₒᵤₜ                                  Rₒᵤₜ

# %% [markdown]
# which can be further manipulated as:

# %%
equation_6 = sp.Eq(equation_5.lhs * Rout, equation_5.rhs * Rout)
equation_6.simplify()
# Out:
#                                                      d
# Rₒᵤₜ⋅\dot{Q}_{gen}(t) + Tₐ - Tₛ(t) = Cₚ⋅(Rᵢₙ + Rₒᵤₜ)⋅──(Tₛ(t))
#                                                      dt

# %% [markdown]
# ## Experimental data wrangling

# %% [markdown]
# ## internal heat generation
#
# Due to its squared relation with current, joule internal heat generation is the only heating source considered in the method we are exploring (Equation [eq:ohmic_res]). To take advantage of that and reduce the error of neglecting the heating source due to internal chemical reactions (entropy), the cell is charged and discharge at the maximum allowed rate by the cell manufacturer. This attempts to amplify the joule heating terms of the process in relation to the entropic ones.
#
# $\dot{Q}_{gen}	=RI^{2} =|(V-V_{OCV}(SOC))\cdot I|$
#
# Where $R[\Omega]$ is the eletrical resistance and $I[A]$ is the current passing through the cell.
#
# Joule heating is also proportional to the voltage drop across the cell (Equation [eq:ohmic_volt_drop]), where Vis the voltage of the cell and $V_{OCV}(SOC)$ is the open circuit voltage (OCV) as function of state of charge (SOC). Note that the absolute value are taking into account because heat is generated both in charge and discharge.
#
# In this method, we measure the open circuit voltage $V_{OCV}$ at $50\%$ of state of charge. According to Forgez et al. (2010), this value was arbitrarlily choosen because at this SOC batteries generally exhibit the maximum charge/discharge power capabilities.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import glob
import os
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
files = glob.glob('data\\*.xlsx')
data = pd.read_excel(files[0], sheet_name=1)
print(files[0])
# Out:
# data\demo_data_Thermal_Char_25degC.xlsx

# %%
data = data[(data['Test_Time(s)']>24000)]



fig, ax1 = plt.subplots(figsize=(7,4))

ax1.plot(data['Test_Time(s)'], data['Voltage(V)'], label='Voltage [V]')
ax2=ax1.twinx()
ax2.plot(data['Test_Time(s)'], data['Current(A)'], label='Current [A]',
        color='r')
ax2.set_ylim([35,-50])
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)
ax1.set_ylabel('Voltage [V]')
ax2.set_ylabel('Current [A]')
ax1.set_xlabel('Running test time [s]')
ax1.grid()

# %%
time_step = []
for i in range(0, len(data['Test_Time(s)'])):
    i = i * 30
    time_step.append(i)
    
data['time_step'] = time_step

size_sample = 500
zoomed_time_step = data['time_step'].iloc[-size_sample:]
zoomed_voltage = data['Voltage(V)'].iloc[-size_sample:]
zoomed_current = data['Current(A)'].iloc[-size_sample:]

fig, ax1 = plt.subplots(figsize=(7,4))
ax1.plot(zoomed_time_step, zoomed_voltage, label='Voltage [V]')
ax2=ax1.twinx()
ax2.plot(zoomed_time_step, zoomed_current, label='Current [A]',
        color='r')
ax2.set_ylim([35,-50])
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)
ax1.set_ylabel('Voltage [V]')
ax2.set_ylabel('Current [A]')
ax1.set_xlabel('Time [s]')
ax1.grid()
ax1.set_title('Current and Voltage profiles (zoomed)')
# Out:
# Text(0.5, 1.0, 'Current and Voltage profiles (zoomed)')

# %%
data['OCV'] = 3.82
data['Q_gen'] = abs((data['Voltage(V)'] - data['OCV']) * data['Current(A)'])
#data['R_out'] = (data['Aux_Temperature_1(C)'] - data['Aux_Temperature_3(C)']) / (data['Q_gen'])
#R_out = data['R_out']

Q_gen = data['Q_gen']
data['Q_gen_mean'] = Q_gen.mean()
print('average_Qgen =', Q_gen.mean())

fig, ax1 = plt.subplots(figsize=(7,4))
ax1.plot(data['time_step'], data['Q_gen'], label='Calculated $\dot{Q}_{gen}$')
ax1.set_ylabel('$\dot{Q}_{gen} [W]$')
ax1.set_xlabel('$Time [s]$')
ax1.plot(data['time_step'], data['Q_gen_mean'], label='Average $\dot{Q}_{gen}=$'+ str(round(Q_gen.mean(),2)) + 'W')
plt.legend(loc = 'upper right')
ax1.grid()
# Out:
# average_Qgen = 1.3314615571529478

# %% [markdown]
# ## External thermal resistance
#
# In order to calculate $R_{out}$, the cell is submited to cycles of charge/discharge pulses of \pm5\% SOC at the maximum allowed C-rates. The cycle is performed until the heat generated by the cell reaches equilibrium state with the ambient. In other words, the surface temperature $T_{s}$ stops increasing and thus the derivative term $\frac{dT_{s}}{dt}$ reaches $\frac{dT_{s}}{dt}=0$ in Equation [eq:heat_balance_final], which combined to Equation [eq:ohmic_volt_drop] becomes:$R_{out}=\frac{(T_{s}-T_{a})}{\dot{Q}_{gen}}$
#
# ## Final section
#
# Now we are going to define the final section of the data where the system is considered thermal stable. First, let's take a look at the overal temperatures:

# %%
fig, ax1 = plt.subplots(figsize=(7,4))

ax1.plot(data['time_step'], data['Aux_Temperature_3(C)'], 
         label='Ambient', color='r')
ax1.plot(data['time_step'], data['Aux_Temperature_1(C)'],
         label='Surface (Thermocouple 1)')
ax1.plot(data['time_step'], data['Aux_Temperature_2(C)'],
         label='Surface (Thermocouple 2)')

ax1.legend(loc=0)
ax1.set_ylabel('Temperature [°C]')
ax1.set_xlabel('Time [s]')
ax1.grid()

# %% [markdown]
# Now, let's arbitrarily consider the final 1/3 of the data as the portion of thermal stability. Certainly there is better ways to evaluate this, such as evaluating the derivatives of a moving average along the data. But for the sake of simplicity let's leave as it is to see how far we can get.

# %%
#this step uses only test cycle data (from the begining of the test cycle, not raw data)

Ts_1 = data['Aux_Temperature_1(C)']
Ts_2 = data['Aux_Temperature_2(C)']
Ta = data['Aux_Temperature_3(C)']



rolling_window = 251
poly_fit = 1
from scipy.signal import savgol_filter
data['Ts_filtered'] = savgol_filter((Ts_1 + Ts_2)/2, rolling_window, poly_fit)
data['Ta_filtered'] = savgol_filter(Ta, rolling_window, poly_fit)

#this step uses only the last 1/3 of the data (ploted)

data_section_final = data.copy()
sample_size = int(len(data)/3)
data_section_final = data_section_final.iloc[-sample_size:]

Ts_1 = data_section_final['Aux_Temperature_1(C)']
Ts_2 = data_section_final['Aux_Temperature_2(C)']
Ta = data_section_final['Aux_Temperature_3(C)']
time_step = data_section_final['time_step']

data_section_final['Ts_mean'] = ((Ts_1 + Ts_2)/2).mean()
data_section_final['Ta_mean'] = Ta.mean()
Ts_mean = data_section_final['Ts_mean']
Ta_mean = data_section_final['Ta_mean']
Ts_filtered = data_section_final['Ts_filtered']
Ta_filtered = data_section_final['Ta_filtered']

fig, ax1 = plt.subplots(figsize=(7,7))

scatter_size = 0.5
ax1.scatter(time_step, Ts_1, label='Surface (Thermocouple 1)', s=scatter_size)
ax1.scatter(time_step, Ts_2, label='Surface (Thermocouple 2)', s=scatter_size)
ax1.scatter(time_step, Ta, label='Ambient Temperature', s=scatter_size)

ax1.plot(time_step, Ts_mean, label='Average Surface Temp =' + str(round(Ts_mean.mean(),2)))
ax1.plot(time_step, Ta_mean, label='Average Ambient Temp =' + str(round(Ta_mean.mean(),2)))
ax1.plot(time_step, Ts_filtered, label='Filtered Surface Temp (Savitzky–Golay)')
ax1.plot(time_step, Ta_filtered, label='Filtered Ambient Temp (Savitzky–Golay)')

#ax2 = ax1.twinx()
#ax2.plot(time_step, data_section_final['Current(A)'])
#ax2.set_ylim([110,-40])

print('Average Surface Temp =' + str(round(Ts_mean.mean(),2)))
print('Average Ambient Temp =' + str(round(Ta_mean.mean(),2)))
print('Average filtered Surface Temp =' + str(round(Ts_filtered.mean(),2)))
print('Average filtered Ambient Temp =' + str(round(Ta_filtered.mean(),2)))

ax1.legend(loc=0)
ax1.set_ylabel('Temperature [°C]')
ax1.set_xlabel('Time [s]')
ax1.grid()
# Out:
# Average Surface Temp =29.23
# Average Ambient Temp =25.54
# Average filtered Surface Temp =29.23
# Average filtered Ambient Temp =25.54

# %% [markdown]
# We can se by the filtered data that the system is not yet totally stable at the final portion. We perhaps will have to make the test longer in the next round of data.
#
# ### Calculating external thermal resistance using raw data vs average values:
#
# Except for outlier values or high levels of noise in the data, is common practice to perform all the calculations with raw data and take the filtering / averaging aftwards to avoid loss of information along the way. In this way, we will test what happens when we calculate the external thermal resistances considering the raw values of temperatures and g_gen:

# %%
# There is no need to convert Ts_mean and Ta to Kelvin because it's a delta diference in the equation
data_section_final['R_out'] = ((Ts_1 + Ts_2)/2 - Ta) / Q_gen

fig, ax1 = plt.subplots(figsize=(7,4))
ax1.plot(data_section_final['time_step'], data_section_final['R_out'], label='Calculated $R_{out}$')
ax2=ax1.twinx()
ax2.plot(data_section_final['time_step'], data_section_final['Current(A)'], label='Current',
        color='r')
ax2.set_ylim([35,-50])
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)
ax1.set_ylabel('Thermal Resistance  [K/W]')
ax2.set_ylabel('Current [A]')
ax1.set_xlabel('Time [s]')
ax1.grid()

# %% [markdown]
# It does not seem to be correct. We can see that when the current changes it's sign there is a peak in the calculated R_out because I reaches 0. Let's take a closer look at what happens with each variable of the equation:

# %%
size_sample = 180
zoomed_time_step = data_section_final['time_step'].iloc[-size_sample:]
zoomed_resistance = data_section_final['R_out'].iloc[-size_sample:]
zoomed_Q_gen = Q_gen.iloc[-size_sample:]
zoomed_Temps = ((Ts_1 + Ts_2)/2 - Ta).iloc[-size_sample:]




fig, ax1 = plt.subplots(figsize=(7,4))
ax1.plot(zoomed_time_step, zoomed_resistance, label='Calculated $R_{out}$')


ax2=ax1.twinx()
ax2.plot(zoomed_time_step, zoomed_Q_gen, label='Calculated $\dot{Q}_{gen}$',
        color='r')
#ax2.set_ylim([10,-5])

ax3 = ax1.twinx()

lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines3, labels3 = ax3.get_legend_handles_labels()

ax2.legend(lines + lines2 + lines3, labels + labels2 + labels3, loc='upper right')
ax1.set_ylabel('Thermal Resistance  [K/W]')
ax2.set_ylabel('$\dot{Q}_{gen}$')
ax1.set_xlabel('Time [s]')
ax1.grid()
#ax1.set_title('Current and calculated $R_{out}$ (zoomed)')



ax3.set_ylabel('ΔT [°C]') 
ax3.tick_params(axis='y')
ax3.spines["right"].set_position(("axes", 1.12))
ax3.plot(zoomed_time_step, zoomed_Temps, label='Ts - Ta', color='g')
ax3.set_ylim([6,1])
# Out:
# (6.0, 1.0)

# %% [markdown]
# In fact the peak is due to I approaching zero value and by consequence Q_gen approaches zero, which makes the External resistance peak at that point. Now let's investigate how this affect the average External resistance. The calculation below takes all raw data seen in the graphic above:

# %%
data_section_final['R_out'].mean()
# Out:
# 10.829849943421939

# %% [markdown]
# Now let's see what happens if instead of raw data we take the averaged temperatures and Q_gen:

# %%
((Ts_mean - Ta.mean()) / Q_gen.mean()).iloc[0]
# Out:
# 2.772751004684448

# %% [markdown]
# A huge difference! Probably this value calculated from the averages will be closer to the value we are expecting because the equation cannot handle properly Q_gen approaching zero

# %% [markdown]
# ## Initial section
#
# In order to calculate internal thermal resistance and heat capacity, we will have to take into consideration the initial part of the data where the system is not stable.
#
# The cutoff point is given by te equation below:

# %%
cutoff_factor = 0.95
cutoff = Ta.mean() + cutoff_factor*(Ts_mean - Ta.mean()).iloc[0]
cutoff
# Out:
# 29.0444418867203

# %%
Ts_1 = data['Aux_Temperature_1(C)']
Ts_2 = data['Aux_Temperature_2(C)']
Ta = data['Aux_Temperature_3(C)']

rolling_window = 241
poly_fit = 1
data['Ts_filtered'] = savgol_filter((Ts_1 + Ts_2)/2, rolling_window, poly_fit)

fig, ax1 = plt.subplots(figsize=(7,4))

ax1.plot(data['time_step'], data['Aux_Temperature_3(C)'], 
         label='Ambient', color='r')
ax1.plot(data['time_step'], data['Aux_Temperature_1(C)'],
         label='Surface (Thermocouple 1)')
ax1.plot(data['time_step'], data['Aux_Temperature_2(C)'],
         label='Surface (Thermocouple 2)')
ax1.plot(data['time_step'], data['Ts_filtered'],
         label='Filtered Surface Temp (Savitzky–Golay)')


ax1.legend(loc=0)
ax1.set_ylabel('Temperature [°C]')
ax1.set_xlabel('Time [s]')
ax1.grid()

# %%
data_section_initial = data.copy()
data_section_initial = data_section_initial[(data_section_initial['Ts_filtered']<cutoff)]

fig, ax1 = plt.subplots(figsize=(7,4))

ax1.plot(data_section_initial['time_step'], data_section_initial['Aux_Temperature_3(C)'], 
         label='Ambient', color='r')
ax1.plot(data_section_initial['time_step'], data_section_initial['Aux_Temperature_1(C)'],
         label='Surface (Thermocouple 1)')
ax1.plot(data_section_initial['time_step'], data_section_initial['Aux_Temperature_2(C)'],
         label='Surface (Thermocouple 2)')
ax1.plot(data_section_initial['time_step'], data_section_initial['Ts_filtered'],
         label='Filtered Surface Temp (Savitzky–Golay)')


ax1.legend(loc=0)
ax1.set_ylabel('Temperature [°C]')
ax1.set_xlabel('Time [s]')
ax1.grid()

# %% [raw]
# from scipy.optimize import least_squares
#
# def y(theta, t):
#     return theta[0] / (1 + np.exp(- theta[1] * (t - theta[2])))
#
# ts = np.linspace(0, 1)
# K = 1; r = 10; t0 = 0.5; noise = 0.1
# ys = y([K, r, t0], ts) + noise * np.random.rand(ts.shape[0])
#
# def fun(theta):
#     return y(theta, ts) - ys
#
# theta0 = [1,2,3]
# res1 = least_squares(fun, theta0)

# %%
ts.shape
# Out:
# (50,)

# %%
plt.plot(res1.fun+ys)
plt.plot(ys)
theta0 = [1,2,3]
fun
# Out:
# <function __main__.fun(theta)>

# %%
Qgen = 3.3
Rout = 2.77
deltaT = 1
Ta = 25

def y(theta, t):
    return (((Qgen*Rout + Ta - theta[2])*(t - theta[3]))/(theta[0]*(theta[1] + Rout))) + theta[2]

ts = np.array(data_section_initial['time_step'])
ys = y([Cp, Rin, Ts, t0], ts)

def fun(theta):
    return y(theta, ts) - ys

theta0 = [1,2,25, 0]
res1 = least_squares(fun, theta0)

plt.plot(res1.fun+ys)
#plt.plot(ys)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-8ad0b3de35e0> in <module>
#      14
#      15 theta0 = [1,2,25, 1]
# ---> 16 res1 = least_squares(fun, theta0)
#      17
#      18 plt.plot(res1.fun+ys)
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     821                          "f0.shape: {0}".format(f0.shape))
#     822
# --> 823     if not np.all(np.isfinite(f0)):
#     824         raise ValueError("Residuals are not finite in the initial point.")
#     825
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
Qgen = 3.3
Rout = 2.77
Ta = 25
deltaT = 15

def y(theta):
    return (((Qgen*Rout + Ta - theta[2])*(deltaT))/(theta[0]*(theta[1] + Rout))) + theta[2]
Cp = 6; Rin = 1; Ts = 30; t0 =0
ts = np.linspace(0, 1)
ys = y([Cp, Rin, Ts])

plt.plot(ys)
print(len(ys))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-492ef849b89e> in <module>
#      11
#      12 plt.plot(ys)
# ---> 13 print(len(ys))
#
# TypeError: object of type 'float' has no len()

# %%
def fun(t, time_step, Ts_initial):
    Ts = []
    Ts.append(Ts_initial)
    for i in range(t):      
        Ts_n = (((Qgen*Rout + Ta - Ts[-1])*(time_step))/(Cp*(Rin + Rout))) + Ts[-1]
        Ts.append(Ts_n)
    
    return Ts
    
    
    
    
x = fun(100, 2, 30)
plt.plot(x)

# %%
Ts = [1,2,3]
Ts[-1]
# Out:
# 3

# %%
deltaT = 15

Ts = 30
Ts_0 = (((Qgen*Rout + Ta - Ts)*(deltaT))/(Cp*(Rin + Rout))) + Ts
Ts_0


Ts = Ts_0
Ts_1 = (((Qgen*Rout + Ta - Ts)*(deltaT))/(Cp*(Rin + Rout))) + Ts
Ts_1


Ts = Ts_1
Ts_2 = (((Qgen*Rout + Ta - Ts)*(deltaT))/(Cp*(Rin + Rout))) + Ts
Ts_2


Ts = Ts_2
Ts_3 = (((Qgen*Rout + Ta - Ts)*(deltaT))/(Cp*(Rin + Rout))) + Ts
Ts_3

x = np.array([Ts_0, Ts_1, Ts_2, Ts_3])
plt.plot(x)

# %%
from scipy.signal import savgol_filter

# %%
moving_average = test_data['Aux_Temperature_1(C)'].rolling(window=199).mean()
moving_average.describe()
filtered = savgol_filter(test_data['Aux_Temperature_1(C)'], 199, 1)
test_data['filtered'] = filtered
test_data['Ts_calculated'] = 0

step = []
for i in range(0, len(moving_average)):
    step.append(i)

test_data['step'] = step
size_sample = int(len(moving_average)/3)
x = test_data['filtered'].iloc[-size_sample:]
x_step = test_data['step'].iloc[-size_sample:]

plt.plot(test_data['step'], test_data['Aux_Temperature_1(C)'])
plt.plot(test_data['step'], moving_average)
plt.plot(test_data['step'], filtered)
plt.plot(x_step, x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-de103e0dde5e> in <module>
# ----> 1 moving_average = test_data['Aux_Temperature_1(C)'].rolling(window=199).mean()
#       2 moving_average.describe()
#       3 filtered = savgol_filter(test_data['Aux_Temperature_1(C)'], 199, 1)
#       4 test_data['filtered'] = filtered
#       5 test_data['Ts_calculated'] = 0
#
# NameError: name 'test_data' is not defined

# %%
x = test_data['filtered'].iloc[-50:]
int(len(moving_average)/3)

# %%
step = []
for i in range(0, len(moving_average)):
    step.append(i)

test_data['step'] = step
test_data['step'].describe()

# %%
print(len(filtered), len(moving_average), len(test_data['Aux_Temperature_1(C)']))

# %% [markdown]
# ## Heat capacity calculations

# %%
Eq1 = sp.Eq(Cp * (Rin + 2.82), 664)
Eq2 = sp.Eq(Cp * (Rin + 1.99), 574)

# %%
sp.solve([Eq1,Eq2], Cp, Rin)

# %%
glob.glob(str(os.getcwd()))
